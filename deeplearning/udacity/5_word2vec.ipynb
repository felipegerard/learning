# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data[:8]
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
tf.nn.embedding_lookup?
#tf.nn.sampled_softmax_loss?

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.948017
# Nearest to d: aalborg, surveys, heritage, lake, nica, hon, reshaped, marcello,
# Nearest to two: universidad, induction, exe, latvia, perseus, soared, spiegel, tantra,
# Nearest to nine: dinara, hallmark, kampen, elbows, encompassing, haddock, backbench, sdp,
# Nearest to seven: latham, retirement, insurrections, bluescreen, pygmy, berwick, hopkinson, rhodesia,
# Nearest to three: stratofortress, linehan, studying, engaging, stakes, noun, nitz, unedited,
# Nearest to some: adoptive, elevate, macron, hatred, resemblance, keith, algeciras, cracker,
# Nearest to and: dis, supermassive, metamorphic, reinvented, frick, wynn, usaid, hose,
# Nearest to of: discontinued, etymological, ende, disseminate, followers, hertogenbosch, batters, waist,
# Nearest to when: proficient, polymath, reverses, concerning, peck, azali, murky, gib,
# Nearest to th: consigned, clip, vico, jewel, tidy, osama, blyth, zarathustra,
# Nearest to however: fishery, figaro, lingering, insulator, northward, maha, porgy, torquato,
# Nearest to not: animal, breastfeeding, cinco, orgy, hani, jason, hallows, isomer,
# Nearest to also: pareto, mpa, stressed, ue, beltaine, cornell, developments, typological,
# Nearest to world: diger, fic, didgeridoo, madelyne, jester, lgpl, industrially, coverage,
# Nearest to be: spicy, lusatia, relational, pogo, brindle, scout, croquet, now,
# Nearest to with: auspicious, mhz, luther, stiffness, timepieces, pablo, soil, paragraphs,
# Average loss at step 2000: 4.357240
# Average loss at step 4000: 3.864367
# Average loss at step 6000: 3.788211
# Average loss at step 8000: 3.691533
# Average loss at step 10000: 3.619372
# Nearest to d: surveys, installments, b, dynamical, hon, funded, lake, pinchcliffe,
# Nearest to two: three, four, five, eight, six, seven, nine, zero,
# Nearest to nine: eight, seven, six, five, zero, three, two, four,
# Nearest to seven: six, eight, five, nine, three, four, zero, two,
# Nearest to three: seven, six, four, eight, two, five, nine, zero,
# Nearest to some: many, ellesmere, maja, algeciras, jehoshaphat, resemblance, thenceforth, detours,
# Nearest to and: or, discern, s, wd, lensing, which, of, were,
# Nearest to of: in, xv, at, workloads, scope, and, for, from,
# Nearest to when: however, gib, polymath, uso, beds, quantitatively, concerning, toured,
# Nearest to th: consigned, clip, blyth, vico, neustadt, cooperating, sandstorms, eight,
# Nearest to however: fishery, when, scientist, instrumentalist, visible, gotha, zeppelins, soaps,
# Nearest to not: it, we, only, still, never, to, they, avoiding,
# Nearest to also: never, bards, callers, transgender, urraca, starred, it, magdalene,
# Nearest to world: diger, fic, didgeridoo, civil, behind, fades, celebrities, haunted,
# Nearest to be: have, is, are, siberian, was, gomez, by, been,
# Nearest to with: in, philippians, into, from, got, for, grease, as,
# Average loss at step 12000: 3.603879
# Average loss at step 14000: 3.569390
# Average loss at step 16000: 3.405076
# Average loss at step 18000: 3.456007
# Average loss at step 20000: 3.537236
# Nearest to d: b, hon, italian, ern, pinchcliffe, benjamin, banknotes, french,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to seven: eight, three, five, six, nine, four, two, zero,
# Nearest to three: four, seven, five, six, eight, two, nine, zero,
# Nearest to some: many, these, several, all, any, algeciras, ellesmere, maja,
# Nearest to and: or, but, wd, from, in, whose, which, between,
# Nearest to of: omnivores, in, for, keystrokes, haus, devas, dissemination, and,
# Nearest to when: however, though, splendid, gib, monastic, but, polymath, before,
# Nearest to th: consigned, clip, firm, chandrasekhar, russians, mg, june, neustadt,
# Nearest to however: but, when, that, praises, although, legionaries, sesame, enthusiasts,
# Nearest to not: we, only, never, they, still, also, to, entirely,
# Nearest to also: now, never, which, emirates, generally, usually, not, still,
# Nearest to world: diger, civil, didgeridoo, celebrities, fades, grandson, serra, title,
# Nearest to be: been, have, was, is, identifiers, platforms, were, gomez,
# Nearest to with: in, between, from, into, philippians, by, craps, and,
# Average loss at step 22000: 3.498333
# Average loss at step 24000: 3.489469
# Average loss at step 26000: 3.480786
# Average loss at step 28000: 3.479273
# Average loss at step 30000: 3.500892
# Nearest to d: b, pinchcliffe, hon, italian, ern, blown, montserrat, odessa,
# Nearest to two: four, three, five, one, seven, eight, six, nine,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to seven: eight, nine, five, six, four, three, zero, two,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to some: many, these, several, all, rpgs, various, any, most,
# Nearest to and: or, against, but, from, in, globin, chuvash, lettering,
# Nearest to of: xv, vorder, in, buchner, mep, from, against, for,
# Nearest to when: after, although, but, however, where, before, though, is,
# Nearest to th: consigned, clip, mg, bc, one, eight, neustadt, chandrasekhar,
# Nearest to however: but, when, although, while, tapes, that, formerly, legionaries,
# Nearest to not: still, entirely, they, typically, only, never, generally, we,
# Nearest to also: now, which, never, below, often, pollard, it, still,
# Nearest to world: diger, civil, grandson, fades, carson, serra, unfavourable, transfusions,
# Nearest to be: been, have, become, identifiers, is, was, are, were,
# Nearest to with: between, philippians, by, into, in, under, against, for,
# Average loss at step 32000: 3.497757
# Average loss at step 34000: 3.491727
# Average loss at step 36000: 3.458204
# Average loss at step 38000: 3.296935
# Average loss at step 40000: 3.422422
# Nearest to d: b, montserrat, UNK, pinchcliffe, odessa, hon, hunnish, jacinto,
# Nearest to two: three, four, six, five, seven, eight, zero, nine,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to seven: nine, six, five, eight, four, three, zero, two,
# Nearest to three: four, six, two, seven, five, eight, nine, zero,
# Nearest to some: many, these, several, any, alike, ellesmere, maja, tswana,
# Nearest to and: or, but, in, UNK, however, while, to, mecha,
# Nearest to of: in, from, aha, xv, unstoppable, and, omnivores, vincendeau,
# Nearest to when: if, before, although, where, after, but, with, while,
# Nearest to th: consigned, clip, ad, mg, bc, ainsworth, rd, nd,
# Nearest to however: but, while, although, that, and, though, squad, when,
# Nearest to not: never, entirely, still, they, typically, generally, ratified, we,
# Nearest to also: often, now, never, which, sometimes, still, below, usually,
# Nearest to world: civil, diger, vietnam, habit, stylistic, grandson, country, carson,
# Nearest to be: been, have, is, become, being, identifiers, avoid, was,
# Nearest to with: between, when, for, on, containing, mutagens, subcategories, cinco,
# Average loss at step 42000: 3.434519
# Average loss at step 44000: 3.449661
# Average loss at step 46000: 3.445240
# Average loss at step 48000: 3.351125
# Average loss at step 50000: 3.383721
# Nearest to d: b, odessa, ghee, e, montserrat, yehudi, l, hunnish,
# Nearest to two: three, four, six, five, eight, one, seven, zero,
# Nearest to nine: eight, seven, six, four, zero, five, three, two,
# Nearest to seven: six, nine, eight, four, three, five, zero, two,
# Nearest to three: six, four, seven, eight, five, two, nine, zero,
# Nearest to some: many, several, these, various, those, most, ellesmere, alike,
# Nearest to and: or, including, of, but, in, smyrnaeans, while, wd,
# Nearest to of: and, in, rstenberg, omnivores, including, indirect, include, leftist,
# Nearest to when: if, although, after, before, where, while, but, though,
# Nearest to th: consigned, ainsworth, mg, ad, bc, nd, clip, rd,
# Nearest to however: but, while, although, though, that, when, where, until,
# Nearest to not: still, never, typically, generally, ratified, they, entirely, who,
# Nearest to also: now, often, never, which, below, still, sometimes, emirates,
# Nearest to world: civil, country, vietnam, largest, fades, diger, grandson, carson,
# Nearest to be: have, been, become, being, were, is, was, identifiers,
# Nearest to with: between, philippians, when, by, mutagens, verdun, into, subcategories,
# Average loss at step 52000: 3.437109
# Average loss at step 54000: 3.428035
# Average loss at step 56000: 3.438372
# Average loss at step 58000: 3.397515
# Average loss at step 60000: 3.392753
# Nearest to d: b, pinchcliffe, surveys, h, ghee, c, l, jacinto,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to some: many, several, these, this, various, any, most, those,
# Nearest to and: or, but, while, deuterostomes, including, keats, although, smyrnaeans,
# Nearest to of: in, for, without, including, omnivores, same, affixes, optimization,
# Nearest to when: although, before, if, after, where, while, because, detainees,
# Nearest to th: nd, consigned, ad, rd, eight, six, bc, mg,
# Nearest to however: but, though, although, that, while, when, until, where,
# Nearest to not: still, ratified, never, chicken, typically, entirely, now, normative,
# Nearest to also: now, often, below, still, never, sometimes, currently, generally,
# Nearest to world: civil, country, fades, diger, advocacy, largest, transfusions, vietnam,
# Nearest to be: been, was, become, is, have, refer, by, being,
# Nearest to with: between, craps, desi, among, containing, by, dacian, preventative,
# Average loss at step 62000: 3.239880
# Average loss at step 64000: 3.251263
# Average loss at step 66000: 3.401057
# Average loss at step 68000: 3.395784
# Average loss at step 70000: 3.359240
# Nearest to d: b, l, odessa, pinchcliffe, h, montserrat, xbox, jacinto,
# Nearest to two: three, four, six, seven, five, eight, one, zero,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to some: many, several, these, various, any, all, most, those,
# Nearest to and: or, but, while, of, including, which, ejaculation, impedes,
# Nearest to of: including, include, and, representing, in, governing, overall, like,
# Nearest to when: if, before, where, while, although, however, after, because,
# Nearest to th: consigned, nineteenth, nd, bc, ad, rd, st, ainsworth,
# Nearest to however: but, though, although, while, that, where, when, which,
# Nearest to not: still, never, now, entirely, typically, chicken, generally, only,
# Nearest to also: often, now, still, which, below, sometimes, never, usually,
# Nearest to world: country, civil, advocacy, largest, stylistic, reorganised, lemurs, diger,
# Nearest to be: been, is, were, become, being, have, identifiers, easily,
# Nearest to with: between, containing, using, mutagens, cerrado, like, amphibious, by,
# Average loss at step 72000: 3.369816
# Average loss at step 74000: 3.351556
# Average loss at step 76000: 3.314170
# Average loss at step 78000: 3.350061
# Average loss at step 80000: 3.378251
# Nearest to d: b, odessa, montserrat, goren, jacinto, p, surveys, h,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to some: many, several, these, various, certain, most, those, any,
# Nearest to and: or, including, while, redshift, by, but, rit, when,
# Nearest to of: in, original, including, solving, ethidium, maoi, dib, tabulate,
# Nearest to when: before, if, after, although, while, though, where, during,
# Nearest to th: bc, rd, consigned, nd, one, nineteenth, ad, pounded,
# Nearest to however: but, although, though, that, where, while, including, when,
# Nearest to not: still, typically, now, generally, never, they, it, usually,
# Nearest to also: now, still, often, below, never, which, usually, currently,
# Nearest to world: country, advocacy, lemurs, reorganised, diger, unfavourable, liberalize, u,
# Nearest to be: been, become, have, being, is, are, avoid, easily,
# Nearest to with: between, through, mutagens, into, in, khanates, bitten, philippians,
# Average loss at step 82000: 3.405330
# Average loss at step 84000: 3.411599
# Average loss at step 86000: 3.386834
# Average loss at step 88000: 3.353324
# Average loss at step 90000: 3.362409
# Nearest to d: b, mandy, goren, p, l, jacinto, intersecting, h,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to seven: eight, five, four, six, nine, three, zero, one,
# Nearest to three: five, two, four, seven, eight, six, nine, zero,
# Nearest to some: many, several, these, those, any, most, certain, various,
# Nearest to and: or, but, including, however, while, ea, through, retract,
# Nearest to of: including, for, include, vorder, in, same, devas, affixes,
# Nearest to when: if, before, after, where, while, although, though, during,
# Nearest to th: seven, rd, bc, nd, consigned, ad, nineteenth, one,
# Nearest to however: but, that, although, though, since, while, and, where,
# Nearest to not: still, we, now, never, they, chicken, therefore, you,
# Nearest to also: now, often, still, which, never, sometimes, below, emirates,
# Nearest to world: country, unfavourable, diger, celesta, stylistic, advocacy, liberalize, winter,
# Nearest to be: been, become, have, is, being, was, refer, avoid,
# Nearest to with: between, in, containing, using, mutagens, celtics, through, by,
# Average loss at step 92000: 3.398631
# Average loss at step 94000: 3.248316
# Average loss at step 96000: 3.356173
# Average loss at step 98000: 3.238570
# Average loss at step 100000: 3.355051
# Nearest to d: b, odessa, cartoons, xbox, h, jacinto, cdot, l,
# Nearest to two: four, five, three, six, eight, seven, zero, one,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to three: four, five, six, two, eight, seven, nine, zero,
# Nearest to some: many, several, these, any, certain, various, those, most,
# Nearest to and: or, but, while, when, although, of, addison, however,
# Nearest to of: and, including, original, integrins, besides, toponyms, phenylalanine, gave,
# Nearest to when: if, before, although, where, while, after, though, because,
# Nearest to th: bc, nd, rd, consigned, nineteenth, ad, ainsworth, luke,
# Nearest to however: but, that, although, though, while, where, since, and,
# Nearest to not: still, never, almost, they, you, typically, now, nor,
# Nearest to also: now, still, often, never, below, sometimes, usually, emirates,
# Nearest to world: country, celesta, videogame, stylistic, hasty, diger, civil, year,
# Nearest to be: been, become, is, being, produce, are, refer, have,
# Nearest to with: between, using, subcategories, mutagens, through, amphibious, in, cinco,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# **NOTE:** My solution *must* use a batch size of 1 (i.e. SGD without minibatch) because I couldn't figure out how to perform aggregation by label. It would have been better to use a bigger minibatch!

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  batch = np.ndarray(shape=(batch_size*(2*skip_window),), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    batch[(2*skip_window*i):(2*skip_window*(i+1))] = [buffer[j] for j in range(len(buffer)) if j != skip_window]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1,2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('===============================')
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch    -->    label')
    for i in range(len(labels)):
        print('-------------------------------')
        for j in range(2*skip_window):
            print('    ',
                  reverse_dictionary[batch[2*skip_window*i+j]],
                  '    ',
                  reverse_dictionary[labels.flatten()[i]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# ===============================
#
# with skip_window = 1:
#     batch    -->    label
# -------------------------------
#      anarchism      originated
#      as      originated
# -------------------------------
#      originated      as
#      a      as
# -------------------------------
#      as      a
#      term      a
# -------------------------------
#      a      term
#      of      term
# -------------------------------
#      term      of
#      abuse      of
# -------------------------------
#      of      abuse
#      first      abuse
# -------------------------------
#      abuse      first
#      used      first
# -------------------------------
#      first      used
#      against      used
# ===============================
#
# with skip_window = 2:
#     batch    -->    label
# -------------------------------
#      anarchism      as
#      originated      as
#      a      as
#      term      as
# -------------------------------
#      originated      a
#      as      a
#      term      a
#      of      a
# -------------------------------
#      as      term
#      a      term
#      of      term
#      abuse      term
# -------------------------------
#      a      of
#      term      of
#      abuse      of
#      first      of
# -------------------------------
#      term      abuse
#      of      abuse
#      first      abuse
#      used      abuse
# -------------------------------
#      of      first
#      abuse      first
#      used      first
#      against      first
# -------------------------------
#      abuse      used
#      first      used
#      against      used
#      early      used
# -------------------------------
#      first      against
#      used      against
#      early      against
#      working      against

# %%
#tf.nn.embedding_lookup?
train_dataset
# Out:
# <tf.Tensor 'Placeholder:0' shape=(1,) dtype=int32>

# %%
batch_size = 1 ### 128 # Usando 1 contexto para predecir 1 palabra
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
#valid_examples = np.array(random.sample(range(valid_window), valid_size)) ### REUSE THE SAME WORDS AND SO COMPARE
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size*(2*skip_window)])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed_sum = tf.reduce_sum(embed,
                            reduction_indices=0,
                            keep_dims=True)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(0.1).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 300001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 10000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 50000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 10.401494
# Nearest to as: incarceration, rationalisation, uppercase, crimson, kickoff, claudio, mitotic, harp,
# Nearest to at: basing, decorator, fragile, haggis, limnic, redox, benefitting, monoxide,
# Nearest to been: manmade, fft, tacit, baton, dives, lorenzo, disrespectful, kombat,
# Nearest to to: certification, galina, hydrographic, macromolecule, wand, mining, squandered, bedi,
# Nearest to other: philistine, separatist, labels, tin, silicates, heroes, impiety, laughs,
# Nearest to they: pilgrims, stm, demonstrable, ghosting, skirt, wormhole, amnesia, magnetometer,
# Nearest to more: atlanteans, approximates, sophie, kickoff, lippincott, byrnes, tiki, milligrams,
# Nearest to there: gestapo, felsic, steve, lethal, alegre, respected, idol, piece,
# Nearest to states: blooms, radioisotopes, kalmyks, webcams, differ, vibrant, rinse, extraction,
# Nearest to than: monologues, syllabus, preprocessor, presentations, knuth, maha, isoroku, dowleh,
# Nearest to who: hydrated, quill, neutrality, aldrin, hub, radians, obliged, stretching,
# Nearest to seven: howlin, equivalently, orthodoxy, taiko, seleucus, samson, dixit, austrofascism,
# Nearest to over: strength, questioning, mcgill, unfortunate, previews, harwood, ewes, tapering,
# Nearest to state: carrel, wrestle, frauds, vending, nva, liberate, santiago, tursiops,
# Nearest to from: slides, afghana, vocally, jalal, hong, bukem, isaias, colloquial,
# Nearest to four: scientifically, rv, huygens, crc, vipassana, lightness, rising, inexperienced,
# Average loss at step 10000: 27.971636
# Average loss at step 20000: 24.790094
# Average loss at step 30000: 22.873955
# Average loss at step 40000: 22.539535
# Average loss at step 50000: 22.006329
# Nearest to as: fifth, knee, incarceration, coda, can, admin, makarios, in,
# Nearest to at: decorator, insofar, basing, cleaved, haggis, meriwether, cryo, limnic,
# Nearest to been: manmade, fft, dives, disrespectful, labyrinth, baton, tacit, kombat,
# Nearest to to: from, in, will, liaison, technique, certification, dancers, insofar,
# Nearest to other: do, krakow, enfield, canola, labels, that, reference, image,
# Nearest to they: stm, ernie, conservative, pilgrims, residences, it, uptake, gulden,
# Nearest to more: sophie, due, atlanteans, milligrams, litovsk, however, behavior, unconditionally,
# Nearest to there: steve, piece, incorporates, gestapo, intelsat, cover, alegre, emanating,
# Nearest to states: radioisotopes, blooms, kalmyks, extraction, disastrously, jamo, cognitivism, jehoash,
# Nearest to than: monologues, one, limburg, grigori, llama, sepp, rosser, peacock,
# Nearest to who: reckless, astronomers, malignant, carib, galicia, consequence, argue, pages,
# Nearest to seven: two, nine, one, four, zero, don, wonderswan, eight,
# Nearest to over: strength, ewes, ran, mcfadden, bis, pushes, mcgill, people,
# Nearest to state: cape, growths, stability, oilers, liberate, nva, n, following,
# Nearest to from: to, vocally, thornton, byng, slides, aggressor, in, four,
# Nearest to four: five, seven, eight, scientifically, motilal, july, two, brewers,
# Average loss at step 60000: 21.442096
# Average loss at step 70000: 21.227994
# Average loss at step 80000: 20.633670
# Average loss at step 90000: 21.042109
# Average loss at step 100000: 20.449447
# Nearest to as: fifth, knee, in, between, and, admin, incarceration, coda,
# Nearest to at: decorator, insofar, cleaved, basing, and, cryo, india, resolves,
# Nearest to been: manmade, dives, alds, labyrinth, fft, was, take, disrespectful,
# Nearest to to: in, from, will, may, liaison, first, anniversary, studies,
# Nearest to other: do, enfield, krakow, reference, ordination, shakes, labels, meagre,
# Nearest to they: stm, ernie, it, he, conservative, sadly, ever, wads,
# Nearest to more: sophie, due, abortion, atlanteans, however, behavior, unconstitutional, never,
# Nearest to there: steve, piece, scholars, respected, incorporates, intelsat, rickshaw, lycus,
# Nearest to states: radioisotopes, blooms, extraction, girl, carl, kalmyks, european, cognitivism,
# Nearest to than: monologues, peacock, one, limburg, rosser, differential, llama, names,
# Nearest to who: reckless, astronomers, malignant, consequence, she, settlers, buson, dmitry,
# Nearest to seven: two, one, nine, four, zero, eight, focal, seleucus,
# Nearest to over: ran, quarter, strength, mcfadden, mcgill, pushes, ewes, advertise,
# Nearest to state: stability, oilers, abol, liberate, following, cape, foldoc, mci,
# Nearest to from: to, in, of, thornton, byng, transliterated, vocally, hated,
# Nearest to four: five, seven, eight, july, two, zero, motilal, brewers,
# Average loss at step 110000: 20.382187
# Average loss at step 120000: 20.251344
# Average loss at step 130000: 19.816825
# Average loss at step 140000: 19.830826
# Average loss at step 150000: 19.836303
# Nearest to as: fifth, in, knee, and, for, short, winters, firm,
# Nearest to at: insofar, cleaved, decorator, and, basing, cryo, every, in,
# Nearest to been: manmade, dives, alds, was, labyrinth, telephus, fft, kombat,
# Nearest to to: in, from, will, may, for, anniversary, first, liaison,
# Nearest to other: enfield, do, reference, ordination, meagre, materials, krakow, members,
# Nearest to they: it, stm, ernie, he, ever, sadly, not, gulden,
# Nearest to more: sophie, due, temperatures, never, milligrams, abortion, litovsk, unconditionally,
# Nearest to there: steve, scholars, areas, piece, lycus, mice, ezekiel, no,
# Nearest to states: radioisotopes, extraction, blooms, thought, carl, confirmed, girl, texts,
# Nearest to than: monologues, differential, peacock, limburg, llama, one, recollections, grigori,
# Nearest to who: she, malignant, reckless, astronomers, settlers, consequence, pages, buson,
# Nearest to seven: two, nine, one, zero, four, o, eight, focal,
# Nearest to over: quarter, ran, strength, auden, objector, mcfadden, rulers, mcgill,
# Nearest to state: stability, abol, oilers, liberate, following, wet, cape, lowest,
# Nearest to from: in, to, of, and, byng, thornton, cantonal, vocally,
# Nearest to four: five, seven, eight, brewers, zero, scientifically, ounces, july,
# Average loss at step 160000: 19.328532
# Average loss at step 170000: 19.615471
# Average loss at step 180000: 19.072037
# Average loss at step 190000: 19.055444
# Average loss at step 200000: 19.155091
# Nearest to as: and, fifth, in, knee, for, winters, partial, firm,
# Nearest to at: insofar, basing, decorator, for, cryo, and, in, cleaved,
# Nearest to been: manmade, was, alds, dives, is, labyrinth, disrespectful, headache,
# Nearest to to: in, will, from, for, not, may, would, theology,
# Nearest to other: enfield, do, governments, undeniable, krakow, reference, materials, labels,
# Nearest to they: it, he, ernie, not, stm, automatic, ever, gulden,
# Nearest to more: sophie, due, unconstitutional, temperatures, milligrams, unconditionally, never, behavior,
# Nearest to there: steve, areas, scholars, lycus, incorporated, he, ezekiel, generally,
# Nearest to states: radioisotopes, blooms, extraction, confirmed, thought, texts, carl, india,
# Nearest to than: monologues, peacock, limburg, llama, much, for, recollections, rosser,
# Nearest to who: she, malignant, settlers, reckless, astronomers, consequence, pages, also,
# Nearest to seven: two, nine, one, zero, four, eight, o, directly,
# Nearest to over: quarter, objector, advertise, harwood, mistaken, mcfadden, auden, ran,
# Nearest to state: stability, liberate, oilers, abol, nva, foldoc, mci, lowest,
# Nearest to from: in, of, to, and, hated, thornton, byng, cantonal,
# Nearest to four: seven, eight, five, zero, brewers, august, two, july,
# Average loss at step 210000: 19.052540
# Average loss at step 220000: 19.019061
# Average loss at step 230000: 18.866503
# Average loss at step 240000: 19.101987
# Average loss at step 250000: 18.974409
# Nearest to as: fifth, in, and, for, is, winters, firm, knee,
# Nearest to at: decorator, insofar, in, basing, and, cleaved, for, benefitting,
# Nearest to been: was, manmade, alds, dives, headache, disrespectful, labyrinth, tacit,
# Nearest to to: in, from, will, for, not, would, might, certification,
# Nearest to other: enfield, do, undeniable, materials, krakow, townships, labels, governments,
# Nearest to they: it, he, ernie, not, stm, ever, automatic, gulden,
# Nearest to more: sophie, unconstitutional, due, temperatures, never, milligrams, kickoff, unconditionally,
# Nearest to there: steve, incorporated, he, scholars, lycus, areas, generally, piece,
# Nearest to states: blooms, radioisotopes, confirmed, extraction, thought, texts, carl, india,
# Nearest to than: monologues, peacock, limburg, much, llama, recollections, for, frisian,
# Nearest to who: she, malignant, also, settlers, we, consequence, astronomers, erowid,
# Nearest to seven: nine, one, two, four, zero, eight, o, five,
# Nearest to over: quarter, mistaken, advertise, harwood, objector, mcfadden, strength, auden,
# Nearest to state: stability, liberate, nva, wet, oilers, foldoc, mci, abol,
# Nearest to from: in, of, to, and, hated, byng, thornton, among,
# Nearest to four: seven, eight, five, zero, august, two, one, brewers,
# Average loss at step 260000: 19.091668
# Average loss at step 270000: 18.909336
# Average loss at step 280000: 18.547432
# Average loss at step 290000: 17.917835
# Average loss at step 300000: 18.382584
# Nearest to as: fifth, for, by, in, kerberos, winters, partial, is,
# Nearest to at: in, decorator, insofar, basing, and, cleaved, vernacular, benefitting,
# Nearest to been: was, manmade, alds, dives, headache, disrespectful, telephus, labyrinth,
# Nearest to to: in, will, from, must, for, not, certification, would,
# Nearest to other: enfield, reference, labels, symbolic, do, townships, governments, undeniable,
# Nearest to they: he, it, stm, ernie, not, automatic, gulden, ever,
# Nearest to more: sophie, unconstitutional, due, never, temperatures, unconditionally, kickoff, milligrams,
# Nearest to there: steve, he, incorporated, generally, scholars, lycus, and, they,
# Nearest to states: blooms, extraction, confirmed, radioisotopes, thought, differ, texts, india,
# Nearest to than: monologues, peacock, knuth, much, limburg, llama, box, for,
# Nearest to who: she, settlers, also, we, malignant, astronomers, connoisseurs, reckless,
# Nearest to seven: two, nine, one, four, zero, eight, three, five,
# Nearest to over: advertise, quarter, mistaken, harwood, objector, mcfadden, vietnam, rulers,
# Nearest to state: stability, oilers, liberate, foldoc, nva, mci, vlaamse, cape,
# Nearest to from: in, of, and, to, among, or, byng, by,
# Nearest to four: seven, eight, five, zero, two, august, brewers, ounces,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
