# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name))
  f.close()
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (mostl likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.294302 learning rate: 10.000000
# Minibatch perplexity: 26.96
# ================================================================================
# krnmbiseq dafpefixv  smvgtspejlysytdkkunddta kiesfweqxeinjkczbtievylik v ecwoaas
# f nmtqb etnpysi fsjpiceidcsebkjcragnq cr ynsjica xq hes ey gqhusdosinif istducbh
# wsior nqa x abs piseloyt xtlmrqbieelof ia aansofjolelz vluiuyo nif mou  trqthjcc
# dutrzbln  t tm crunpsdaepktkenssi a trcybowa  xldejysleomwedtcveeor m otheotoaqn
# knhafeoownndjfbygmdo mhpxiniosgtfmvt y ned  nxbses hw or petakakombomugijmvougdz
# ================================================================================
# Validation set perplexity: 19.87
# Average loss at step 100: 2.598290 learning rate: 10.000000
# Minibatch perplexity: 10.26
# Validation set perplexity: 10.87
# Average loss at step 200: 2.255170 learning rate: 10.000000
# Minibatch perplexity: 9.54
# Validation set perplexity: 9.00
# Average loss at step 300: 2.099015 learning rate: 10.000000
# Minibatch perplexity: 7.65
# Validation set perplexity: 8.01
# Average loss at step 400: 2.001806 learning rate: 10.000000
# Minibatch perplexity: 7.49
# Validation set perplexity: 7.67
# Average loss at step 500: 1.937362 learning rate: 10.000000
# Minibatch perplexity: 6.35
# Validation set perplexity: 7.02
# Average loss at step 600: 1.914545 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.71
# Average loss at step 700: 1.862995 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 6.74
# Average loss at step 800: 1.823880 learning rate: 10.000000
# Minibatch perplexity: 6.26
# Validation set perplexity: 6.51
# Average loss at step 900: 1.834680 learning rate: 10.000000
# Minibatch perplexity: 7.25
# Validation set perplexity: 6.26
# Average loss at step 1000: 1.829300 learning rate: 10.000000
# Minibatch perplexity: 5.95
# ================================================================================
# ne in the lader sints univers diralies delijed entwonding juciorasion ippetfere
# zity tho ears lare infreederal an exin the raning of anist d dlaminien s pruled
# ly fhollen to with one nine zictled or did an and bayy wlith then in lictritiona
# nish was frezerih bun what can six nateran will flich in filss wnereations with
#  se stalthings is sugtime firealiblizes gying with in serdisper of the spries b
# ================================================================================
# Validation set perplexity: 6.12
# Average loss at step 1100: 1.780675 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 5.88
# Average loss at step 1200: 1.760234 learning rate: 10.000000
# Minibatch perplexity: 6.21
# Validation set perplexity: 5.66
# Average loss at step 1300: 1.739117 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 5.67
# Average loss at step 1400: 1.752825 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.66
# Average loss at step 1500: 1.748792 learning rate: 10.000000
# Minibatch perplexity: 6.09
# Validation set perplexity: 5.68
# Average loss at step 1600: 1.751997 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.57
# Average loss at step 1700: 1.720259 learning rate: 10.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 5.59
# Average loss at step 1800: 1.676389 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 5.32
# Average loss at step 1900: 1.650045 learning rate: 10.000000
# Minibatch perplexity: 5.97
# Validation set perplexity: 5.39
# Average loss at step 2000: 1.699864 learning rate: 10.000000
# Minibatch perplexity: 4.87
# ================================================================================
# y and resinet evil kimeiel and this common the sametar forcenna crowds are excen
# perburaity it reloft it rerolutist disa to schoolds the dirien nately one nine e
# perrobles the genunallogasted catlain of didalla s was adecy see quirent and whi
# er wnewher witl sfet in the hending kindinsomed the deptoriantants and upperotel
# oper one nine eighe four three two zero twreat they behdions poporevine to the t
# ================================================================================
# Validation set perplexity: 5.22
# Average loss at step 2100: 1.693708 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.04
# Average loss at step 2200: 1.687882 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.15
# Average loss at step 2300: 1.643764 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.83
# Average loss at step 2400: 1.666838 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.91
# Average loss at step 2500: 1.686375 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.78
# Average loss at step 2600: 1.659692 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 4.77
# Average loss at step 2700: 1.658859 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.66
# Average loss at step 2800: 1.654304 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.53
# Average loss at step 2900: 1.652895 learning rate: 10.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.61
# Average loss at step 3000: 1.650279 learning rate: 10.000000
# Minibatch perplexity: 4.67
# ================================================================================
# t in one one feth mz time it papticcicial dony vowate to kince four one six eigh
# re be one six conpirale in probar was yemben if a state that widercan sovered th
# k without rmpphwant ay hirclabe wpicley numper callenting interper in anding n s
# ars all be jean amire corlors in cheutabomor amount dvremals court the recial yh
# ver occume way this one nine five the eventation thine then one three three two
# ================================================================================
# Validation set perplexity: 4.82
# Average loss at step 3100: 1.635550 learning rate: 10.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 4.70
# Average loss at step 3200: 1.648926 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.59
# Average loss at step 3300: 1.641924 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 4.53
# Average loss at step 3400: 1.672077 learning rate: 10.000000
# Minibatch perplexity: 5.87
# Validation set perplexity: 4.52
# Average loss at step 3500: 1.661620 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.65
# Average loss at step 3600: 1.668190 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.57
# Average loss at step 3700: 1.649016 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.60
# Average loss at step 3800: 1.645233 learning rate: 10.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.57
# Average loss at step 3900: 1.640761 learning rate: 10.000000
# Minibatch perplexity: 5.81
# Validation set perplexity: 4.59
# Average loss at step 4000: 1.650120 learning rate: 10.000000
# Minibatch perplexity: 4.76
# ================================================================================
# ai commant diezal seen prounty are sumo relument here main were demisiving daver
# zations bylared on whrougher its a govined om becompited the othout dinging unte
# y comsperatent resigninis pertoing lay oraliticle reviced or game calty over app
# ushtocless nated  region on the furthar bylewed friming and world overtionally p
#  while theew one five one nine nine nine seven one nine four history but ax a so
# ================================================================================
# Validation set perplexity: 4.59
# Average loss at step 4100: 1.637847 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.66
# Average loss at step 4200: 1.635363 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.52
# Average loss at step 4300: 1.618473 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.55
# Average loss at step 4400: 1.608638 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.50
# Average loss at step 4500: 1.617089 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.78
# Average loss at step 4600: 1.616218 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.51
# Average loss at step 4700: 1.629398 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.49
# Average loss at step 4800: 1.632121 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.47
# Average loss at step 4900: 1.634893 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.60
# Average loss at step 5000: 1.608326 learning rate: 1.000000
# Minibatch perplexity: 5.51
# ================================================================================
# n of the eliger par see abouts even one became counting fup chure tenned to term
# menthoced five nine nine four one nine zero five nine eight two one five as laje
# fide frondendided the using the packing acle nounty worth she dioaly mahis by bu
# fel communation in the thishing that non a wire puths only mar highersy was disd
# s in one would to the secrance in jauriem that exsure work the is one nine five
# ================================================================================
# Validation set perplexity: 4.57
# Average loss at step 5100: 1.605947 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.40
# Average loss at step 5200: 1.594024 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.34
# Average loss at step 5300: 1.582963 learning rate: 1.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.34
# Average loss at step 5400: 1.581716 learning rate: 1.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.32
# Average loss at step 5500: 1.566836 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.27
# Average loss at step 5600: 1.580103 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.28
# Average loss at step 5700: 1.570669 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.28
# Average loss at step 5800: 1.583726 learning rate: 1.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.28
# Average loss at step 5900: 1.571953 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.28
# Average loss at step 6000: 1.549073 learning rate: 1.000000
# Minibatch perplexity: 4.85
# ================================================================================
# ver increatess onlinents the two reddizoine wellers trains lsdd it of a of decor
# fical these is a strumber and batting worke the lines aren history the offames j
# x have sa with m term those one nine zero two one two and interctup with the hem
#  all the conjentation reway with the madid zero fide is as small so paving and u
# hare and aral out of by about he sondemanke is al andue defection and fashe heam
# ================================================================================
# Validation set perplexity: 4.27
# Average loss at step 6100: 1.563633 learning rate: 1.000000
# Minibatch perplexity: 4.21
# Validation set perplexity: 4.26
# Average loss at step 6200: 1.545637 learning rate: 1.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.27
# Average loss at step 6300: 1.545450 learning rate: 1.000000
# Minibatch perplexity: 4.42
# Validation set perplexity: 4.25
# Average loss at step 6400: 1.543329 learning rate: 1.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.24
# Average loss at step 6500: 1.558412 learning rate: 1.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.26
# Average loss at step 6600: 1.600903 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.24
# Average loss at step 6700: 1.581476 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.23
# Average loss at step 6800: 1.606288 learning rate: 1.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.24
# Average loss at step 6900: 1.584308 learning rate: 1.000000
# Minibatch perplexity: 4.48
# Validation set perplexity: 4.28
# Average loss at step 7000: 1.580952 learning rate: 1.000000
# Minibatch perplexity: 4.88
# ================================================================================
# jesist of with velected that natural will one nine four nine four four two zero
# waring now obsenfined are west ruther city on gu use than alfre well of rather k
# jessi nemert favid french at in one nine were the citymentated haed by getrally
# ters addosoges were are photon addition action the countined and scales for lest
# velntly remorm unders axage becauser but recorded to the huduetch type that whin
# ================================================================================
# Validation set perplexity: 4.26

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    wi = tf.concat(1, [ix, fx, cx, ox])
    input_prod = tf.matmul(i, wi)
    pix, pfx, pcx, pox = tf.split(1, 4, input_prod)
    
    wo = tf.concat(1, [im, fm, cm, om])
    output_prod = tf.matmul(o, wo)
    pim, pfm, pcm, pom = tf.split(1, 4, output_prod)
    
    input_gate = tf.sigmoid(pix + pim + ib)
    forget_gate = tf.sigmoid(pfx + pfm + fb)
    update = pcx + pcm + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(pox + pom + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293575 learning rate: 10.000000
# Minibatch perplexity: 26.94
# ================================================================================
# ktvieo  tuhju xx bk di h  mj   oe rpn nte e efevy l fqa llstmdv e taiexhroxrdd o
# n sie swbu zsuz jeujalevg hlfs aerr rtlaevlrnvsagesb ah eey uetag vrurcexyo fils
# u crdexgisnztzmol yjxzp ywzxmc   iiw zdcgpnzbuuzra taevpicfveoulnspsnvodz nebdpi
# ktttepdzgwfydpieirilkoehvu foiss c qrl pg op fvsukeobgesssleifp ccvijlcszvjehetk
# d lkee mhduiaivnkeeenq jteqdtmndykgc reiioown az wt dgndaeriltwnvrz iqweotk huh
# ================================================================================
# Validation set perplexity: 20.17
# Average loss at step 100: 2.593014 learning rate: 10.000000
# Minibatch perplexity: 10.22
# Validation set perplexity: 10.51
# Average loss at step 200: 2.263190 learning rate: 10.000000
# Minibatch perplexity: 9.28
# Validation set perplexity: 8.99
# Average loss at step 300: 2.096265 learning rate: 10.000000
# Minibatch perplexity: 7.56
# Validation set perplexity: 8.10
# Average loss at step 400: 2.035861 learning rate: 10.000000
# Minibatch perplexity: 6.98
# Validation set perplexity: 7.73
# Average loss at step 500: 1.976583 learning rate: 10.000000
# Minibatch perplexity: 6.69
# Validation set perplexity: 7.10
# Average loss at step 600: 1.891787 learning rate: 10.000000
# Minibatch perplexity: 6.37
# Validation set perplexity: 6.75
# Average loss at step 700: 1.868156 learning rate: 10.000000
# Minibatch perplexity: 7.12
# Validation set perplexity: 6.71
# Average loss at step 800: 1.860769 learning rate: 10.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 6.37
# Average loss at step 900: 1.837558 learning rate: 10.000000
# Minibatch perplexity: 6.61
# Validation set perplexity: 6.33
# Average loss at step 1000: 1.840936 learning rate: 10.000000
# Minibatch perplexity: 6.24
# ================================================================================
# man lapp sure he c duridish ifforts and the can the manisus poter it was the opp
# blically with in thereverestatessiant shiggent one one note one be sturidsfure m
# purored spacks in may nabureb blagie bugill whow has rill osh an trounser rember
# vebering anderites andut in corinere it stril chtw dueith welk wide u sport the
# larys by maki van pageral g t b one nine two letter b one wero sewne three akces
# ================================================================================
# Validation set perplexity: 6.05
# Average loss at step 1100: 1.795753 learning rate: 10.000000
# Minibatch perplexity: 5.86
# Validation set perplexity: 6.05
# Average loss at step 1200: 1.763315 learning rate: 10.000000
# Minibatch perplexity: 6.12
# Validation set perplexity: 5.88
# Average loss at step 1300: 1.752824 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 5.92
# Average loss at step 1400: 1.758209 learning rate: 10.000000
# Minibatch perplexity: 6.12
# Validation set perplexity: 5.86
# Average loss at step 1500: 1.744201 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 5.46
# Average loss at step 1600: 1.728891 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 5.68
# Average loss at step 1700: 1.711851 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 5.61
# Average loss at step 1800: 1.685583 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 5.56
# Average loss at step 1900: 1.694509 learning rate: 10.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 5.46
# Average loss at step 2000: 1.676686 learning rate: 10.000000
# Minibatch perplexity: 5.66
# ================================================================================
# jove to we comels liks a degiled to extraated prigitaly hereapheration placulati
# k sterf and third the iderable and polise dase connecting lower there by to by a
# wan ares the pollids three six wored and ve magariated fartiod but dankt inforit
# ected frequent trad sucpore n chadigls its typpe in post plasically inucrean rec
# f directs extanled forthitibe wored sequenty and pore it iflure is sudon of blo
# ================================================================================
# Validation set perplexity: 5.48
# Average loss at step 2100: 1.685882 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 5.26
# Average loss at step 2200: 1.705399 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 5.26
# Average loss at step 2300: 1.709692 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 5.36
# Average loss at step 2400: 1.681264 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 5.34
# Average loss at step 2500: 1.688583 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 5.23
# Average loss at step 2600: 1.671857 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 5.11
# Average loss at step 2700: 1.682775 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 5.26
# Average loss at step 2800: 1.677999 learning rate: 10.000000
# Minibatch perplexity: 4.39
# Validation set perplexity: 5.23
# Average loss at step 2900: 1.674669 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 5.08
# Average loss at step 3000: 1.681102 learning rate: 10.000000
# Minibatch perplexity: 4.88
# ================================================================================
# k five fies butory three senning to ofter ploodents to and as br by depigental s
# x flyjatounly extice in one prevaling can one nine nine nine six nine one eight
# fring priabitius partia rails and visies ald operaters of ratesured specially th
# velies his chincred torkal most dovy this many yen be shurch crojection aim as a
# ast sofiess micy and aren to k briad is larth of the was westeral on the asage s
# ================================================================================
# Validation set perplexity: 5.02
# Average loss at step 3100: 1.653511 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 5.03
# Average loss at step 3200: 1.631336 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 5.00
# Average loss at step 3300: 1.645974 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 4.83
# Average loss at step 3400: 1.633837 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.97
# Average loss at step 3500: 1.672246 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.87
# Average loss at step 3600: 1.654076 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.79
# Average loss at step 3700: 1.649097 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 5.01
# Average loss at step 3800: 1.659339 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 4.79
# Average loss at step 3900: 1.650598 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.86
# Average loss at step 4000: 1.643668 learning rate: 10.000000
# Minibatch perplexity: 5.16
# ================================================================================
#  was accuation of herop dua g god even dightard y inte but prosests that one two
# ponal politic colorgela cousses with per electic one five schaze gas prisis from
# cism grast paints concractly to ind abrilatorscit in it of was boots coutt of th
# zars into ong th therrei indown agrepitan kingtisej and the of worlds of is asse
# y two zero zero two zero zero one libe for its editional hiving briew auner site
# ================================================================================
# Validation set perplexity: 4.72
# Average loss at step 4100: 1.620398 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.66
# Average loss at step 4200: 1.616877 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 4.74
# Average loss at step 4300: 1.619674 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.79
# Average loss at step 4400: 1.610740 learning rate: 10.000000
# Minibatch perplexity: 5.97
# Validation set perplexity: 4.85
# Average loss at step 4500: 1.643216 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 5.03
# Average loss at step 4600: 1.623615 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 4.90
# Average loss at step 4700: 1.620200 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 5.01
# Average loss at step 4800: 1.609600 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.89
# Average loss at step 4900: 1.624752 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 4.80
# Average loss at step 5000: 1.613034 learning rate: 1.000000
# Minibatch perplexity: 4.68
# ================================================================================
# ve treate which speigracors a one objact of three zero zero zero up magently of
# ybic success is telmochimed creatchism of which island showj finnspi at halvants
# ments in of ukome in the by to grunets to be all veryigd their one six to to one
# ritzers langualsiablershas strume that doom reterels ves religure x two csine ot
# t rall agripenditists flueus writibe is with the black contempulation accuts gri
# ================================================================================
# Validation set perplexity: 4.78
# Average loss at step 5100: 1.594104 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.68
# Average loss at step 5200: 1.590663 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.65
# Average loss at step 5300: 1.595312 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 4.64
# Average loss at step 5400: 1.592018 learning rate: 1.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.58
# Average loss at step 5500: 1.592186 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.57
# Average loss at step 5600: 1.560775 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.54
# Average loss at step 5700: 1.580818 learning rate: 1.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.50
# Average loss at step 5800: 1.599972 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.55
# Average loss at step 5900: 1.585727 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.52
# Average loss at step 6000: 1.585238 learning rate: 1.000000
# Minibatch perplexity: 4.82
# ================================================================================
# zer s having the isure about scuoble see from areas dasic and timpi turtic swill
# g furmul pock of one eight hivers five throult p warrigered titusman a disported
# nation with the featureline since part state militar angations like about to wit
# g were poses by seters at us of nethory physically three zero three phe of s uci
# noway othones cans a surgion luker retreacon tac nimize five a functive of many
# ================================================================================
# Validation set perplexity: 4.48
# Average loss at step 6100: 1.578240 learning rate: 1.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.53
# Average loss at step 6200: 1.589203 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.54
# Average loss at step 6300: 1.587041 learning rate: 1.000000
# Minibatch perplexity: 6.15
# Validation set perplexity: 4.55
# Average loss at step 6400: 1.568987 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.55
# Average loss at step 6500: 1.559809 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.55
# Average loss at step 6600: 1.603852 learning rate: 1.000000
# Minibatch perplexity: 6.33
# Validation set perplexity: 4.56
# Average loss at step 6700: 1.568645 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.55
# Average loss at step 6800: 1.578945 learning rate: 1.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.59
# Average loss at step 6900: 1.574470 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.54
# Average loss at step 7000: 1.590791 learning rate: 1.000000
# Minibatch perplexity: 5.21
# ================================================================================
# n aptairel over to move exterstation guens english casons information six kmpila
# le liter was first are feat releasely angia berning dietions accities a forke an
# ritation it the prister the also not poutuin for the monstation were one nine tw
# owal buss propertial system on their tycated untilabe to the airfer dlew dessine
# d spepirans composia a earth the guined harmoder bass theins use american consis
# ================================================================================
# Validation set perplexity: 4.51

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
